# %%
# draw without replacement for the numbers -- DONE
# no non resource tiles on outer ring
# add 3:1 trade, etc
# make ocean even more common maybe 0.75/0.25 -- DONE
# for outer ring, disallow tile placements where there is only 1 edge (i.e. sort the tile placements so that 2 edge ones are first)
# some cases where there are NONE of any number on the board
# really need real starting locations, some spots way too good

# maybe make single or double tile clusters more likely to have better numbers

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import hexes
import numpy as np
from generate import CatanBoard
from hexes import TileType

board = CatanBoard(n_players=8,enable_bonus_rolls=True)
board.gen_map()
board.plot()

# %%
a = [1,2,3]
b = [2,3]

# %%
a + b
# Out:
# [1, 2, 3, 2, 3]

# %%
print(type(a))
# Out:
# <class 'list'>
