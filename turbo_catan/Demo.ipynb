# %%
from generate import CatanBoard
from hexes import TileType

# %%
# Out:
# {'3': 1,
#  '4': 1,
#  '5': 1,
#  '6': 1,
#  '8': 1,
#  '9': 1,
#  '10': 1,
#  '11': 1,
#  '2|12': 0.5,
#  '2|2': 0.5,
#  '12|12': 0.5}

# %%
board = CatanBoard(n_players=3,enable_bonus_rolls=True)
board.total_tiles_per_player = 10
board.gen_map()
board.plot()
